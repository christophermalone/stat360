# %% [markdown]
# <a href="https://colab.research.google.com/github/christophermalone/stat360/blob/main/Handout13_Multicollinearity_VariableImportance_ModelMetrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Handout #13 : Multicollinearity, Variable Importance, and Model Metrics

# %% [markdown]
# <table width='100%' ><tr><td bgcolor='green'></td></tr></table>
#
# ## MN Gay Marriage Amendment
#
# Consider the following data collected on counties from all across Minnesota.  The goal here is to investigate the relationship between the outcome from the 2012 ballot measure to restrict marriage between a man and women in the State of MN and various demographics. <table>
#   <tr>
#     <td width='50%'>
#       <ul>
#         <li>Response Variable: Percent Voted Yes for Amendment #1</li><br>
#         <li>Variables under investigation (i.e. independent variables)</li>
#         <ul>
#           <li>% Voted Democrat</li>
#           <li>% Voted Republican</li>
#           <li>Population Per Square Mile</li>
#           <li>Per Capita Income</li>
#           <li>Average Household Size</li>
#           <li>% Bachelor or higher Education</li>
#           <li>% Unemployment</li>
#           <li>% Population Living in Poverty</li>
#           <li>% of Population: Age 0-17</li>
#           <li>% of Population: Age 18-24</li>
#           <li>% of Population: Age 25-44</li>
#           <li>% of Population: Age 45-64</li>
#           <li>% of Population: Age 65 and Over</li>
#           <li>% of Population: White</li>
#           <li>% of Population: African American</li>
#           <li>% of Population: American Indian</li>
#           <li>% of Population: Asian</li>
#           <li>% of Population: Other</li>
#           <li>% of Population: Of Hispanic Origin</li>
#          </ul>
#      </ul>
#     </td>
#     <td width='50%'>
#     <p align='center'><img src="https://drive.google.com/uc?export=view&id=1yat57mNueWJ95pux9YstUjp2JuTc7E9t" width="50%" height="50%"></img></p>
#
#   </td>
# </tr>
# <tr>
#     <td colspan='2' width='100%'>
#     The following is the actual ballot.  A vote of Yes suggests only a union of a man and a women shall be recognized as a marriage in Minnesota.
#      <p align='center'><img src="https://drive.google.com/uc?export=view&id=1QpvU-viFXzqRyiKdZXs-GhLa9OnFvBRb"></img></p>
#
#
#   </td>
# </tr>
# </table>
#
# Data Folder: [OneDrive](https://mnscu-my.sharepoint.com/:f:/g/personal/aq7839yd_minnstate_edu/EmOQfrwxzzRBqq8PH_8qTmMBy-1qKgM11Hb8vzjs025EEA?e=wyShYs)
#
#
#
# <table width='100%' ><tr><td bgcolor='green'></td></tr></table>

# %% [markdown]
# ## Load tidyverse

# %% [markdown]
# The tidyverse R package will be used to assist with reading in the dataset into the current R session.

# %%
#@title Load Tidyverse
#load tidyverse package
library(tidyverse)

# %% [markdown]
# ---

# %% [markdown]
# ## Load the initial data

# %%
# Reading data in using read_csv 
MN_Marriage_Amendment <- read_csv("http://www.StatsClass.org/stat360/Datasets/MN_Marriage_Amendment.csv")
# Out:
# Rows: 87 Columns: 23
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (2): State, County
# dbl (21): FIPSCode, Pct_Yes, Pct_Democrat, Pct_Republican, PopPerSqMile, Per...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# Taking a quick look at the initial data...

# %%
head(MN_Marriage_Amendment)
# Out:
#   FIPSCode State County               Pct_Yes Pct_Democrat Pct_Republican
# 1 27001    MN    Aitkin County, MN    61.82   48.4         49.8
# 2 27003    MN    Anoka County, MN     50.61   47.7         50.3
# 3 27005    MN    Becker County, MN    62.92   41.8         56.4
# 4 27007    MN    Beltrami County, MN  51.08   53.8         43.9
# 5 27009    MN    Benton County, MN    55.39   41.9         55.6
# 6 27011    MN    Big Stone County, MN 67.05   48.3         49.8
#   PopPerSqMile PerCapitaIncome AvgHousehold Size Pct_Bachelororhigher ⋯
# 1   8.9        24694           2.06              15.1                 ⋯
# 2 782.1        29894           2.70              25.8                 ⋯
# 3  24.7        25233           2.38              21.4                 ⋯
# 4  17.7        21753           2.56              29.1                 ⋯
# 5  94.2        23924           2.48              18.8                 ⋯
# 6  10.6        24960           2.15              16.8                 ⋯
#   Pct_Age18to24 Pct_Age25to44 Pct_Age45to64 Pct_Age65andOlder Pct_RaceWhite
# 1  5.1          16.9          32.8          28.5              96
# 2  8.1          27.8          28.4          10.8              87
# 3  6.8          21.7          29.5          18.3              88
# 4 14.6          22.3          25.1          13.7              75
# 5 10.7          28.5          24.2          12.8              95
# 6  5.6          18.4          29.8          25.4              98
#   Pct_RaceAfricanAmerican Pct_RaceAmericanIndian Pct_RaceAsian Pct_RaceOther
# 1 0.4                      2.4                   0.2           0.2
# 2 4.0                      1.0                   4.0           1.5
# 3 0.4                      8.0                   0.4           0.3
# 4 0.6                     20.0                   0.7           0.3
# 5 1.9                      0.4                   1.1           0.4
# 6 0.2                      0.4                   0.1           0.3
#   Pct_Hispanic
# 1 0.9
# 2 3.6
# 3 1.2
# 4 1.5
# 5 1.6
# 6 0.8

# %% [markdown]
# ## Multicollinearity via a Simple Case

# %% [markdown]
# *    Model #1: % Yes ~ % Democrat + % Age 65 and Over
# *    Model #2: % Yes ~ % Republican % Age 65 and Over
# *    Model #3: % Yes ~ % Democrat + % Republican + % Age 65 and Over

# %% [markdown]
# Model #1: $PctYes \sim PctDemocrat + PctAge65andOlder$

# %%
Model_Democrat_Age65 <- lm(Pct_Yes ~ Pct_Democrat + Pct_Age65andOlder, data=MN_Marriage_Amendment) 
summary(Model_Democrat_Age65)
# Out:
# Call:
# lm(formula = Pct_Yes ~ Pct_Democrat + Pct_Age65andOlder, data = MN_Marriage_Amendment)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -15.027  -2.701  -0.142   2.881  14.680
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)       77.17205    4.05593  19.027  < 2e-16 ***
# Pct_Democrat      -0.79755    0.07247 -11.006  < 2e-16 ***
# Pct_Age65andOlder  1.13363    0.11887   9.537 4.94e-15 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.695 on 84 degrees of freedom
# Multiple R-squared:  0.7199,	Adjusted R-squared:  0.7132
# F-statistic: 107.9 on 2 and 84 DF,  p-value: < 2.2e-16

# %% [markdown]
# Consider the scatterplot matrix of the variables in this model.

# %%
pairs(MN_Marriage_Amendment[,c(4,5,17)])
# Out:
# plot without title

# %% [markdown]
# Model #2: $PctYes \sim PctRepublican + PctAge65andOlder$

# %%
Model_Republican_Age65 <- lm(Pct_Yes ~ Pct_Republican + Pct_Age65andOlder, data=MN_Marriage_Amendment) 
summary(Model_Republican_Age65)
# Out:
# Call:
# lm(formula = Pct_Yes ~ Pct_Republican + Pct_Age65andOlder, data = MN_Marriage_Amendment)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -14.5842  -2.5013  -0.3745   2.8525  14.1546
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)       -0.56829    4.20928  -0.135    0.893
# Pct_Republican     0.79185    0.07155  11.068  < 2e-16 ***
# Pct_Age65andOlder  1.12956    0.11849   9.533 5.02e-15 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.68 on 84 degrees of freedom
# Multiple R-squared:  0.7217,	Adjusted R-squared:  0.7151
# F-statistic: 108.9 on 2 and 84 DF,  p-value: < 2.2e-16

# %% [markdown]
# Consider the scatterplot matrix of the variables in this model.

# %%
pairs(MN_Marriage_Amendment[,c(4,6,17)])
# Out:
# plot without title

# %% [markdown]
# Model #3: $PctYes \sim PctDemocrat + PctRepublican + PctAge65andOlder$

# %%
Model_Democrat_Republican_Age65 <- lm(Pct_Yes ~ Pct_Democrat + Pct_Republican + Pct_Age65andOlder, data=MN_Marriage_Amendment) 
summary(Model_Democrat_Republican_Age65)
# Out:
# Call:
# lm(formula = Pct_Yes ~ Pct_Democrat + Pct_Republican + Pct_Age65andOlder,
#     data = MN_Marriage_Amendment)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -14.3475  -2.3834  -0.2877   2.9756  13.8517
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)       -45.9434   154.1379  -0.298    0.766
# Pct_Democrat        0.4663     1.5834   0.294    0.769
# Pct_Republican      1.2533     1.5685   0.799    0.427
# Pct_Age65andOlder   1.1272     0.1194   9.441 8.56e-15 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.705 on 83 degrees of freedom
# Multiple R-squared:  0.722,	Adjusted R-squared:  0.712
# F-statistic: 71.85 on 3 and 83 DF,  p-value: < 2.2e-16

# %% [markdown]
# Consider the scatterplot matrix of the variables in this model.

# %%
pairs(MN_Marriage_Amendment[,c(4,5,6,17)])
# Out:
# plot without title

# %% [markdown]
# ---
#
#
#
# ---
#
# ## Partial Correlations

# %% [markdown]
# The **ppcor** package will be used to obtain the partial correlations.

# %%
install.packages("ppcor")
library(ppcor)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# Model #1: Partial Correlations for Predictors in this Model

# %%
pcor(MN_Marriage_Amendment[,c(4,5,17)])
# Out:
# $estimate
#                      Pct_Yes Pct_Democrat Pct_Age65andOlder
# Pct_Yes            1.0000000   -0.7684406         0.7210072
# Pct_Democrat      -0.7684406    1.0000000         0.5462101
# Pct_Age65andOlder  0.7210072    0.5462101         1.0000000
#
# $p.value
#                        Pct_Yes Pct_Democrat Pct_Age65andOlder
# Pct_Yes           0.000000e+00 5.808736e-18      4.940813e-15
# Pct_Democrat      5.808736e-18 0.000000e+00      5.335266e-08
# Pct_Age65andOlder 4.940813e-15 5.335266e-08      0.000000e+00
#
# $statistic
#                      Pct_Yes Pct_Democrat Pct_Age65andOlder
# Pct_Yes             0.000000   -11.005849          9.536553
# Pct_Democrat      -11.005849     0.000000          5.976373
# Pct_Age65andOlder   9.536553     5.976373          0.000000
#
# $n
# [1] 87
#
# $gp
# [1] 1
#
# $method
# [1] "pearson"

# %% [markdown]
# Model #2: Partial Correlations for Predictors in this Model

# %%
pcor(MN_Marriage_Amendment[,c(4,6,17)])
# Out:
# $estimate
#                     Pct_Yes Pct_Republican Pct_Age65andOlder
# Pct_Yes           1.0000000      0.7701962         0.7208890
# Pct_Republican    0.7701962      1.0000000        -0.5460575
# Pct_Age65andOlder 0.7208890     -0.5460575         1.0000000
#
# $p.value
#                        Pct_Yes Pct_Republican Pct_Age65andOlder
# Pct_Yes           0.000000e+00   4.389470e-18      5.015828e-15
# Pct_Republican    4.389470e-18   0.000000e+00      5.390151e-08
# Pct_Age65andOlder 5.015828e-15   5.390151e-08      0.000000e+00
#
# $statistic
#                     Pct_Yes Pct_Republican Pct_Age65andOlder
# Pct_Yes            0.000000      11.067554          9.533296
# Pct_Republican    11.067554       0.000000         -5.973994
# Pct_Age65andOlder  9.533296      -5.973994          0.000000
#
# $n
# [1] 87
#
# $gp
# [1] 1
#
# $method
# [1] "pearson"

# %% [markdown]
# Model #3: Partial Correlations for Predictors in this Model

# %%
pcor(MN_Marriage_Amendment[,c(4,5,6,17)])
# Out:
# $estimate
#                      Pct_Yes Pct_Democrat Pct_Republican Pct_Age65andOlder
# Pct_Yes           1.00000000   0.03230768     0.08736773        0.71959783
# Pct_Democrat      0.03230768   1.00000000    -0.99743102        0.02261282
# Pct_Republican    0.08736773  -0.99743102     1.00000000       -0.01655128
# Pct_Age65andOlder 0.71959783   0.02261282    -0.01655128        1.00000000
#
# $p.value
#                        Pct_Yes Pct_Democrat Pct_Republican Pct_Age65andOlder
# Pct_Yes           0.000000e+00 7.691183e-01   4.265633e-01      8.560690e-15
# Pct_Democrat      7.691183e-01 0.000000e+00   8.257088e-97      8.372445e-01
# Pct_Republican    4.265633e-01 8.257088e-97   0.000000e+00      8.804915e-01
# Pct_Age65andOlder 8.560690e-15 8.372445e-01   8.804915e-01      0.000000e+00
#
# $statistic
#                     Pct_Yes Pct_Democrat Pct_Republican Pct_Age65andOlder
# Pct_Yes           0.0000000    0.2944907      0.7990132         9.4411470
# Pct_Democrat      0.2944907    0.0000000   -126.8544581         0.2060653
# Pct_Republican    0.7990132 -126.8544581      0.0000000        -0.1508100
# Pct_Age65andOlder 9.4411470    0.2060653     -0.1508100         0.0000000
#
# $n
# [1] 87
#
# $gp
# [1] 2
#
# $method
# [1] "pearson"

# %% [markdown]
# ---
#
#
#
# ---
#
# ## Install car package to obtain Added Variable Plots

# %% [markdown]
# The car package will be used to obtain the added variable plots for each model.

# %%
install.packages("car")
library(car)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message in install.packages("car"):
# “installation of package ‘car’ had non-zero exit status”

# %% [markdown]
# The avPlots() function from the car package can be used to obtained the added variable plots.

# %%
#Model 1 - Added Variable Plots
avPlots(Model_Democrat_Age65)
# Out:
# Plot with title “”

# %%
#Model 2 - Added Variable Plots
avPlots(Model_Republican_Age65)
# Out:
# Plot with title “”

# %%
#Model 3: Added Variable Plots
avPlots(Model_Democrat_Republican_Age65)
# Out:
# Plot with title “”

# %% [markdown]
# ## Variance Inflation Factor

# %% [markdown]
# The **variance inflaction factor** can be used to identify multicollinearity in a linear model.
#
# $$ VIF_{i} = \frac{1}{1-R^{2}_{i}}$$
#
# where $R^{2}_{i}$ is the r-squared from fitting predictor $i$ against all other predictors being considered.

# %% [markdown]
# The following are general guidelines for the use of VIF to identify multicollinearity.
# *   **Near 1**:  indicate the predictor variable is not correlated to others
# *   **Between 1 and 5**: indicate the predictor variable is moderately correlated with one or more other predictor variables
# *   **Greater than 5**: indicate the predictor variable is highly correlated to one or more other predictor variables

# %% [markdown]
# For example, to compute $VIF_{\% Democrat}$ , one must first obtain the $R^{2}$ from the model $PctDemocrat \sim PctRepublican + PctAge65andOlder$ , and then use this value to compute the variance inflation factor.

# %%
#Computing the Variance Inflation Factor for % Democrat
Model_PctDemocrat <- lm(Pct_Democrat ~ Pct_Republican + Pct_Age65andOlder, data=MN_Marriage_Amendment)
summary(Model_PctDemocrat)

cat("\nVariance Inflation Factor:")
cat("\n = 1 / (1 - 0.9979) = 476")
# Out:
# Call:
# lm(formula = Pct_Democrat ~ Pct_Republican + Pct_Age65andOlder,
#     data = MN_Marriage_Amendment)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.86850 -0.19215  0.05095  0.22060  0.79136
#
# Coefficients:
#                    Estimate Std. Error  t value Pr(>|t|)
# (Intercept)       97.307548   0.291637  333.660   <2e-16 ***
# Pct_Republican    -0.989553   0.004957 -199.624   <2e-16 ***
# Pct_Age65andOlder  0.004983   0.008209    0.607    0.546
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3242 on 84 degrees of freedom
# Multiple R-squared:  0.9979,	Adjusted R-squared:  0.9978
# F-statistic: 1.993e+04 on 2 and 84 DF,  p-value: < 2.2e-16
# Variance Inflation Factor:
#  = 1 / (1 - 0.9979) = 476

# %%
#Computing the Variance Inflation Factor for % Democrat
Model_PctDemocrat <- lm(Pct_Democrat ~ Pct_Republican + Pct_Age65andOlder, data=MN_Marriage_Amendment)
summary(Model_PctDemocrat)
# Out:
# Call:
# lm(formula = Pct_Democrat ~ Pct_Republican + Pct_Age65andOlder,
#     data = MN_Marriage_Amendment)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.86850 -0.19215  0.05095  0.22060  0.79136
#
# Coefficients:
#                    Estimate Std. Error  t value Pr(>|t|)
# (Intercept)       97.307548   0.291637  333.660   <2e-16 ***
# Pct_Republican    -0.989553   0.004957 -199.624   <2e-16 ***
# Pct_Age65andOlder  0.004983   0.008209    0.607    0.546
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3242 on 84 degrees of freedom
# Multiple R-squared:  0.9979,	Adjusted R-squared:  0.9978
# F-statistic: 1.993e+04 on 2 and 84 DF,  p-value: < 2.2e-16

# %% [markdown]
# ## Getting Variance Inflation Factor via car package

# %%
#Using vif() function from car package to compute the variance inflation factor 
# for the predictors in the model

vif(Model_Democrat_Republican_Age65)
# Out:
#      Pct_Democrat    Pct_Republican Pct_Age65andOlder
#        475.550957        475.606862          1.004818

# %% [markdown]
# ## Considering all available predictors

# %% [markdown]
# Begin, by considering the correlation martrix of all available predictors.

# %%
cor(MN_Marriage_Amendment[,-c(1,2,3)])
# Out:
#                         Pct_Yes     Pct_Democrat Pct_Republican PopPerSqMile
# Pct_Yes                  1.00000000 -0.64541723   0.64855039    -0.53041263
# Pct_Democrat            -0.64541723  1.00000000  -0.99894342     0.37191654
# Pct_Republican           0.64855039 -0.99894342   1.00000000    -0.36857228
# PopPerSqMile            -0.53041263  0.37191654  -0.36857228     1.00000000
# PerCapitaIncome         -0.58523594  0.11144680  -0.10841808     0.47466412
# AvgHousehold Size       -0.22417766 -0.22015197   0.22121860     0.15928657
# Pct_Bachelororhigher    -0.80645228  0.33506309  -0.33302413     0.55810156
# Pct_Unemployment        -0.13263376  0.06280675  -0.06055333     0.08051932
# Pct_Poverty              0.02110171  0.32594164  -0.32040113     0.07147410
# Pct_Age0to17             0.05515810 -0.36309429   0.36874121     0.09151799
# Pct_Age18to24           -0.46969158  0.28983180  -0.29602847     0.14263643
# Pct_Age25to44           -0.51759911 -0.02059607   0.01717944     0.43221398
# Pct_Age45to64            0.19715487  0.01602144  -0.01403094    -0.18676379
# Pct_Age65andOlder        0.56205416 -0.01768341   0.02074151    -0.35790885
# Pct_RaceWhite            0.35410407 -0.40693647   0.39367509    -0.47722039
# Pct_RaceAfricanAmerican -0.62448520  0.39436745  -0.39157020     0.87190275
# Pct_RaceAmericanIndian  -0.04270261  0.23406644  -0.22374977    -0.06369211
# Pct_RaceAsian           -0.49015819  0.25613803  -0.25029886     0.80909140
# Pct_RaceOther            0.06715177  0.05432809  -0.04548360     0.15702456
# Pct_Hispanic             0.03335616  0.08144261  -0.07372257     0.15640253
#                         PerCapitaIncome AvgHousehold Size Pct_Bachelororhigher
# Pct_Yes                 -0.58523594     -0.22417766       -0.80645228
# Pct_Democrat             0.11144680     -0.22015197        0.33506309
# Pct_Republican          -0.10841808      0.22121860       -0.33302413
# PopPerSqMile             0.47466412      0.15928657        0.55810156
# PerCapitaIncome          1.00000000      0.27115894        0.79479494
# AvgHousehold Size        0.27115894      1.00000000        0.31680898
# Pct_Bachelororhigher     0.79479494      0.31680898        1.00000000
# Pct_Unemployment        -0.19078697      0.10079381       -0.10974819
# Pct_Poverty             -0.57685091     -0.27360631       -0.20875873
# Pct_Age0to17             0.20689757      0.81791868        0.13361938
# Pct_Age18to24           -0.07964962      0.18717769        0.37380549
# Pct_Age25to44            0.53901582      0.74131029        0.55709983
# Pct_Age45to64            0.01437633     -0.56742618       -0.26488150
# Pct_Age65andOlder       -0.41245387     -0.81782806       -0.58926856
# Pct_RaceWhite           -0.08533944     -0.29735936       -0.34647139
# Pct_RaceAfricanAmerican  0.53232438      0.26925262        0.67307644
# Pct_RaceAmericanIndian  -0.27033934      0.06231724       -0.05150966
# Pct_RaceAsian            0.52365535      0.33859399        0.64673209
# Pct_RaceOther            0.02447708      0.21935603        0.01824289
# Pct_Hispanic             0.02487226      0.24339077        0.02423263
#                         Pct_Unemployment Pct_Poverty  Pct_Age0to17
# Pct_Yes                 -0.13263376       0.021101708  0.05515810
# Pct_Democrat             0.06280675       0.325941638 -0.36309429
# Pct_Republican          -0.06055333      -0.320401128  0.36874121
# PopPerSqMile             0.08051932       0.071474101  0.09151799
# PerCapitaIncome         -0.19078697      -0.576850914  0.20689757
# AvgHousehold Size        0.10079381      -0.273606313  0.81791868
# Pct_Bachelororhigher    -0.10974819      -0.208758733  0.13361938
# Pct_Unemployment         1.00000000       0.373032871  0.08185164
# Pct_Poverty              0.37303287       1.000000000 -0.31396539
# Pct_Age0to17             0.08185164      -0.313965391  1.00000000
# Pct_Age18to24           -0.11596182       0.313302982 -0.17341161
# Pct_Age25to44            0.08094233      -0.367481044  0.65387694
# Pct_Age45to64            0.11607661      -0.060441452 -0.48139886
# Pct_Age65andOlder       -0.05005931       0.206803640 -0.62662253
# Pct_RaceWhite           -0.21768385      -0.452875277 -0.29143896
# Pct_RaceAfricanAmerican  0.02054073       0.049115661  0.12666305
# Pct_RaceAmericanIndian   0.30717306       0.544473893  0.15137945
# Pct_RaceAsian           -0.07896740      -0.068062315  0.23314888
# Pct_RaceOther           -0.13597407      -0.019664817  0.19417292
# Pct_Hispanic            -0.11057930      -0.001461885  0.22242698
#                         Pct_Age18to24 Pct_Age25to44 Pct_Age45to64
# Pct_Yes                 -0.4696915847 -0.51759911    0.197154870
# Pct_Democrat             0.2898317955 -0.02059607    0.016021439
# Pct_Republican          -0.2960284709  0.01717944   -0.014030942
# PopPerSqMile             0.1426364281  0.43221398   -0.186763792
# PerCapitaIncome         -0.0796496181  0.53901582    0.014376326
# AvgHousehold Size        0.1871776871  0.74131029   -0.567426180
# Pct_Bachelororhigher     0.3738054888  0.55709983   -0.264881498
# Pct_Unemployment        -0.1159618192  0.08094233    0.116076608
# Pct_Poverty              0.3133029818 -0.36748104   -0.060441452
# Pct_Age0to17            -0.1734116084  0.65387694   -0.481398857
# Pct_Age18to24            1.0000000000  0.18670207   -0.649569340
# Pct_Age25to44            0.1867020723  1.00000000   -0.548505767
# Pct_Age45to64           -0.6495693398 -0.54850577    1.000000000
# Pct_Age65andOlder       -0.4773388128 -0.89494712    0.641285839
# Pct_RaceWhite           -0.1848269845 -0.27286990    0.288040497
# Pct_RaceAfricanAmerican  0.3078447792  0.59474367   -0.363249617
# Pct_RaceAmericanIndian  -0.0008087399 -0.13385782    0.002043753
# Pct_RaceAsian            0.2511320648  0.53194493   -0.353398846
# Pct_RaceOther            0.0674348977  0.17442696   -0.290952110
# Pct_Hispanic             0.0951793148  0.19562864   -0.320925220
#                         Pct_Age65andOlder Pct_RaceWhite Pct_RaceAfricanAmerican
# Pct_Yes                  0.56205416        0.35410407   -0.62448520
# Pct_Democrat            -0.01768341       -0.40693647    0.39436745
# Pct_Republican           0.02074151        0.39367509   -0.39157020
# PopPerSqMile            -0.35790885       -0.47722039    0.87190275
# PerCapitaIncome         -0.41245387       -0.08533944    0.53232438
# AvgHousehold Size       -0.81782806       -0.29735936    0.26925262
# Pct_Bachelororhigher    -0.58926856       -0.34647139    0.67307644
# Pct_Unemployment        -0.05005931       -0.21768385    0.02054073
# Pct_Poverty              0.20680364       -0.45287528    0.04911566
# Pct_Age0to17            -0.62662253       -0.29143896    0.12666305
# Pct_Age18to24           -0.47733881       -0.18482698    0.30784478
# Pct_Age25to44           -0.89494712       -0.27286990    0.59474367
# Pct_Age45to64            0.64128584        0.28804050   -0.36324962
# Pct_Age65andOlder        1.00000000        0.33967547   -0.52571396
# Pct_RaceWhite            0.33967547        1.00000000   -0.52459548
# Pct_RaceAfricanAmerican -0.52571396       -0.52459548    1.00000000
# Pct_RaceAmericanIndian   0.01829740       -0.72667791   -0.11485571
# Pct_RaceAsian           -0.50753944       -0.52844353    0.84018815
# Pct_RaceOther           -0.15402813       -0.30475509    0.30846405
# Pct_Hispanic            -0.19214296       -0.30002276    0.31602596
#                         Pct_RaceAmericanIndian Pct_RaceAsian Pct_RaceOther
# Pct_Yes                 -0.0427026098          -0.49015819    0.06715177
# Pct_Democrat             0.2340664416           0.25613803    0.05432809
# Pct_Republican          -0.2237497669          -0.25029886   -0.04548360
# PopPerSqMile            -0.0636921085           0.80909140    0.15702456
# PerCapitaIncome         -0.2703393380           0.52365535    0.02447708
# AvgHousehold Size        0.0623172436           0.33859399    0.21935603
# Pct_Bachelororhigher    -0.0515096583           0.64673209    0.01824289
# Pct_Unemployment         0.3071730600          -0.07896740   -0.13597407
# Pct_Poverty              0.5444738928          -0.06806232   -0.01966482
# Pct_Age0to17             0.1513794466           0.23314888    0.19417292
# Pct_Age18to24           -0.0008087399           0.25113206    0.06743490
# Pct_Age25to44           -0.1338578236           0.53194493    0.17442696
# Pct_Age45to64            0.0020437526          -0.35339885   -0.29095211
# Pct_Age65andOlder        0.0182974035          -0.50753944   -0.15402813
# Pct_RaceWhite           -0.7266779109          -0.52844353   -0.30475509
# Pct_RaceAfricanAmerican -0.1148557116           0.84018815    0.30846405
# Pct_RaceAmericanIndian   1.0000000000          -0.11940208   -0.17959447
# Pct_RaceAsian           -0.1194020785           1.00000000    0.39245561
# Pct_RaceOther           -0.1795944713           0.39245561    1.00000000
# Pct_Hispanic            -0.1686719210           0.35629295    0.96418746
#                         Pct_Hispanic
# Pct_Yes                  0.033356164
# Pct_Democrat             0.081442613
# Pct_Republican          -0.073722569
# PopPerSqMile             0.156402530
# PerCapitaIncome          0.024872262
# AvgHousehold Size        0.243390772
# Pct_Bachelororhigher     0.024232629
# Pct_Unemployment        -0.110579303
# Pct_Poverty             -0.001461885
# Pct_Age0to17             0.222426981
# Pct_Age18to24            0.095179315
# Pct_Age25to44            0.195628637
# Pct_Age45to64           -0.320925220
# Pct_Age65andOlder       -0.192142957
# Pct_RaceWhite           -0.300022758
# Pct_RaceAfricanAmerican  0.316025957
# Pct_RaceAmericanIndian  -0.168671921
# Pct_RaceAsian            0.356292945
# Pct_RaceOther            0.964187464
# Pct_Hispanic             1.000000000

# %% [markdown]
# The following list of predictors will be retained after completing the appropriate correlation analysis.  A model that includes only these predictors is less likely to have multicollinearity concerns.

# %% [markdown]
# List of predictor variables to be used when building an inital model.
#
# *   Pct_Republican
# *   PerCaptiaIncome
# *   Pct_Bachelororhigher
# *   Pct_Unemployment
# *   Pct_Poverty
# *   Pct_Age0to17
# *   Pct_Age18to24
# *   Pct_Age45to64
# *   Pct_Age65andOlder
# *   Pct_RaceWhite
# *   Pct_RaceAfricanAmerican
# *   Pct_RaceAmericanIndian
# *   Pct_RaceOther

# %%
#Fitting an initial model with all available predictors
Model_Initial <- lm(Pct_Yes ~ Pct_Republican 
                              + PerCapitaIncome + Pct_Bachelororhigher 
                              + Pct_Unemployment + Pct_Poverty 
                              + Pct_Age0to17 + Pct_Age18to24 + Pct_Age45to64 + Pct_Age65andOlder
                              + Pct_RaceWhite + Pct_RaceAfricanAmerican + Pct_RaceAmericanIndian + Pct_RaceOther ,
                              data=MN_Marriage_Amendment
                   )
summary(Model_Initial)
# Out:
# Call:
# lm(formula = Pct_Yes ~ Pct_Republican + PerCapitaIncome + Pct_Bachelororhigher +
#     Pct_Unemployment + Pct_Poverty + Pct_Age0to17 + Pct_Age18to24 +
#     Pct_Age45to64 + Pct_Age65andOlder + Pct_RaceWhite + Pct_RaceAfricanAmerican +
#     Pct_RaceAmericanIndian + Pct_RaceOther, data = MN_Marriage_Amendment)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -5.3185 -1.4731 -0.0521  1.4843  6.4936
#
# Coefficients:
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)             18.8512110 41.6679373   0.452  0.65231
# Pct_Republican           0.5268397  0.0520197  10.128 1.48e-15 ***
# PerCapitaIncome         -0.0005900  0.0002270  -2.599  0.01129 *
# Pct_Bachelororhigher    -0.3185019  0.1030311  -3.091  0.00282 **
# Pct_Unemployment        -1.6493002  0.3258654  -5.061 3.01e-06 ***
# Pct_Poverty              0.1833830  0.1831922   1.001  0.32011
# Pct_Age0to17             1.1719541  0.4567580   2.566  0.01235 *
# Pct_Age18to24            0.0003671  0.3346352   0.001  0.99913
# Pct_Age45to64            0.1504863  0.3299896   0.456  0.64972
# Pct_Age65andOlder        1.0399711  0.2314472   4.493 2.58e-05 ***
# Pct_RaceWhite           -0.0897461  0.2734590  -0.328  0.74371
# Pct_RaceAfricanAmerican  0.0843408  0.6086867   0.139  0.89018
# Pct_RaceAmericanIndian  -0.1798115  0.3220504  -0.558  0.57833
# Pct_RaceOther            0.2388400  0.3509267   0.681  0.49828
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.423 on 73 degrees of freedom
# Multiple R-squared:  0.9352,	Adjusted R-squared:  0.9236
# F-statistic: 81.01 on 13 and 73 DF,  p-value: < 2.2e-16

# %%
tvalue_df <- data.frame(tvalues = abs(summary(Model_Initial)$coefficients[,3]))
tvalue_df$Predictor <- rownames(tvalue_df)
tvalue_df
# Out:
#                         tvalues      Predictor
# (Intercept)              0.452415268 (Intercept)
# Pct_Republican          10.127699521 Pct_Republican
# PerCapitaIncome          2.599412526 PerCapitaIncome
# Pct_Bachelororhigher     3.091319136 Pct_Bachelororhigher
# Pct_Unemployment         5.061292286 Pct_Unemployment
# Pct_Poverty              1.001041670 Pct_Poverty
# Pct_Age0to17             2.565809804 Pct_Age0to17
# Pct_Age18to24            0.001096923 Pct_Age18to24
# Pct_Age45to64            0.456033390 Pct_Age45to64
# Pct_Age65andOlder        4.493341061 Pct_Age65andOlder
# Pct_RaceWhite            0.328188332 Pct_RaceWhite
# Pct_RaceAfricanAmerican  0.138561886 Pct_RaceAfricanAmerican
# Pct_RaceAmericanIndian   0.558333322 Pct_RaceAmericanIndian
# Pct_RaceOther            0.680597982 Pct_RaceOther

# %%
ggplot(tvalue_df, aes(x=reorder(Predictor,-tvalues), y=tvalues))+
 geom_bar(stat="identity") +
 theme(axis.text.x=element_text(angle=90)) +
 labs(title="Variable Importance",
        x ="Predictor Variable", y = "| t value |")
# Out:
# plot without title

# %%
#Computing t-value for significance
qt(0.05/2, df=73, lower.tail=FALSE)
# Out:
# [1] 1.99

# %%
ggplot(tvalue_df, aes(x=reorder(Predictor,-tvalues), y=tvalues))+
 geom_bar(stat="identity") +
 theme(axis.text.x=element_text(angle=90)) +
 labs(title="Variable Importance Plot",
        x ="Predictor Variable", y = "| t value |") +
 geom_hline(yintercept=1.99)  #Bars above this line have non-zero slope
# Out:
# plot without title

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# Getting the sums of square in the marginal distribution for Pct_Yes...

# %%
(MN_Marriage_Amendment
  %>% summarize(SS= (87-1)*var(Pct_Yes))
)
# Out:
#   SS
# 1 6610.529

# %% [markdown]
# Getting the sums of squares for the residuals -- the variation that remains unexplained.

# %%
anova(Model_Initial)
# Out:
#                         Df Sum Sq      Mean Sq     F value     Pr(>F)
# Pct_Republican           1 2780.505076 2780.505076 473.6683278 1.211685e-33
# PerCapitaIncome          1 1773.589820 1773.589820 302.1369503 1.168829e-27
# Pct_Bachelororhigher     1  821.067112  821.067112 139.8715252 1.235964e-18
# Pct_Unemployment         1  230.315632  230.315632  39.2350372 2.335733e-08
# Pct_Poverty              1   43.037161   43.037161   7.3315241 8.433667e-03
# Pct_Age0to17             1    8.093459    8.093459   1.3787478 2.441310e-01
# Pct_Age18to24            1  295.496651  295.496651  50.3388416 6.942141e-10
# Pct_Age45to64            1   54.723453   54.723453   9.3223231 3.157640e-03
# Pct_Age65andOlder        1  115.913679  115.913679  19.7462823 3.092843e-05
# Pct_RaceWhite            1    2.142963    2.142963   0.3650609 5.475821e-01
# Pct_RaceAfricanAmerican  1   21.917220   21.917220   3.7336716 5.720654e-02
# Pct_RaceAmericanIndian   1   32.486941   32.486941   5.5342590 2.134597e-02
# Pct_RaceOther            1    2.719134    2.719134   0.4632136 4.982790e-01
# Residuals               73  428.521095    5.870152          NA           NA

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Model with Statistically Significant Predictors Only

# %%
#Model with only the predictors that are statistically significant
Model_ImportantPredictors  <- lm(Pct_Yes ~ Pct_Republican 
                                          + PerCapitaIncome + Pct_Bachelororhigher 
                                          + Pct_Unemployment 
                                          + Pct_Age0to17 + Pct_Age65andOlder, 
                                          data=MN_Marriage_Amendment
                   )
summary(Model_ImportantPredictors)
# Out:
# Call:
# lm(formula = Pct_Yes ~ Pct_Republican + PerCapitaIncome + Pct_Bachelororhigher +
#     Pct_Unemployment + Pct_Age0to17 + Pct_Age65andOlder, data = MN_Marriage_Amendment)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -5.8516 -1.4814 -0.1775  1.2298  7.1905
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)          20.5293161  6.0239969   3.408 0.001027 **
# Pct_Republican        0.4960096  0.0471489  10.520  < 2e-16 ***
# PerCapitaIncome      -0.0005811  0.0001427  -4.072 0.000109 ***
# Pct_Bachelororhigher -0.3141274  0.0831901  -3.776 0.000305 ***
# Pct_Unemployment     -1.5786127  0.2789739  -5.659 2.29e-07 ***
# Pct_Age0to17          1.0807781  0.1674609   6.454 7.78e-09 ***
# Pct_Age65andOlder     1.0100931  0.1143705   8.832 1.88e-13 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.519 on 80 degrees of freedom
# Multiple R-squared:  0.9232,	Adjusted R-squared:  0.9174
# F-statistic: 160.2 on 6 and 80 DF,  p-value: < 2.2e-16

# %% [markdown]
# ## Model with No Age or No Race Predictors

# %%
#Model with No Age and No Race variables
Model_NoAge_NoRace <- lm(Pct_Yes ~ Pct_Republican 
                                   + PerCapitaIncome + Pct_Bachelororhigher 
                                   + Pct_Unemployment , 
                                   data=MN_Marriage_Amendment
                   )
summary(Model_NoAge_NoRace)
# Out:
# Call:
# lm(formula = Pct_Yes ~ Pct_Republican + PerCapitaIncome + Pct_Bachelororhigher +
#     Pct_Unemployment, data = MN_Marriage_Amendment)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.5137 -2.4036  0.3936  1.9415  9.0079
#
# Coefficients:
#                       Estimate Std. Error t value Pr(>|t|)
# (Intercept)          62.444258   5.036628  12.398  < 2e-16 ***
# Pct_Republican        0.522887   0.059101   8.847 1.45e-13 ***
# PerCapitaIncome      -0.000205   0.000189  -1.085    0.281
# Pct_Bachelororhigher -0.741662   0.092646  -8.005 6.82e-12 ***
# Pct_Unemployment     -1.654073   0.381575  -4.335 4.11e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.501 on 82 degrees of freedom
# Multiple R-squared:  0.848,	Adjusted R-squared:  0.8405
# F-statistic: 114.3 on 4 and 82 DF,  p-value: < 2.2e-16

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Variance Inflaction Factors for Models

# %%
#VIF for Model_Initial
cat("\nVIF for Initial Model\n\n")
data.frame(vif=vif(Model_Initial))

#VIF for Model_ImportantPredictors
cat("\nVIF for Model with Important Predictors\n\n")
data.frame(vif=vif(Model_ImportantPredictors))

#VIF for Model with No Age and No Race
cat("\nVIF for Model with No Age or No Race \n\n")
data.frame(vif=vif(Model_NoAge_NoRace))
# Out:
# VIF for Initial Model
#                         vif
# Pct_Republican           1.973072
# PerCapitaIncome          9.040251
# Pct_Bachelororhigher     8.434801
# Pct_Unemployment         1.593879
# Pct_Poverty              4.994400
# Pct_Age0to17            19.725105
# Pct_Age18to24           20.077662
# Pct_Age45to64           10.462672
# Pct_Age65andOlder       14.241572
# Pct_RaceWhite           56.369022
# Pct_RaceAfricanAmerican 20.515863
# Pct_RaceAmericanIndian  40.103417
# Pct_RaceOther            6.087456
# VIF for Model with Important Predictors
#                      vif
# Pct_Republican       1.498935
# PerCapitaIncome      3.305343
# Pct_Bachelororhigher 5.085257
# Pct_Unemployment     1.080282
# Pct_Age0to17         2.451913
# Pct_Age65andOlder    3.215979
# VIF for Model with No Age or No Race
#                      vif
# Pct_Republican       1.219744
# PerCapitaIncome      3.001373
# Pct_Bachelororhigher 3.266352
# Pct_Unemployment     1.046681

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Added Variable Plots for Models

# %%
#Added Variable Plots for Model_Initial
cat("\nAdded Variable Plots for Initial Model")
avPlots(Model_Initial)
# Out:
# Added Variable Plots for Initial Model
# Plot with title “”
# Plot with title “”

# %%
#VIF for Model_ImportantPredictors
cat("\nAdded Variable Plots for Model with Important Predictors\n\n")
avPlots(Model_ImportantPredictors)
# Out:
# Added Variable Plots for Model with Important Predictors
# Plot with title “”

# %%
#Added Variable Plots for Model with No Age and No Race
cat("\nAdded Variable Plots for Model with No Age or No Race\n\n")
avPlots(Model_NoAge_NoRace)
# Out:
# Added Variable Plots for Model with No Age or No Race
# Plot with title “”

# %% [markdown]
# ## AIC and BIC Metrics for Model Performance

# %%
AIC(Model_Initial, Model_ImportantPredictors, Model_NoAge_NoRace)
# Out:
#                           df AIC
# Model_Initial             15 415.6109
# Model_ImportantPredictors  8 416.3820
# Model_NoAge_NoRace         6 471.7744

# %%
BIC(Model_Initial, Model_ImportantPredictors, Model_NoAge_NoRace)
# Out:
#                           df BIC
# Model_Initial             15 452.5995
# Model_ImportantPredictors  8 436.1093
# Model_NoAge_NoRace         6 486.5699

# %% [markdown]
# End of Document
